# %% [markdown]
# <a href="https://colab.research.google.com/github/WadeChao1011/Pokemon/blob/master/Gengar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install requests
from requests import exceptions
import requests
import cv2
import os
import gevent

# poke name to download
pokemon = 'Gengar'
output = 'dataset/Gengar'

API_KEY = "0712ef347d8d4a828ecf7a7c51da2325"
MAX_RESULTS = 250
GROUP_SIZE = 50

# set the endpoint API URL
URL = "https://api.cognitive.microsoft.com/bing/v7.0/images/search"

# when attempting to download images from the web both the Python
# programming language and the requests library have a number of
# exceptions that can be thrown so let's build a list of them now
# so we can filter on them
EXCEPTIONS = {IOError, FileNotFoundError, exceptions.RequestException, exceptions.HTTPError, exceptions.ConnectionError,
              exceptions.Timeout}

# store the search term in a convenience variable then set the
# headers and search parameters
term = pokemon
headers = {"Ocp-Apim-Subscription-Key": API_KEY}
params = {"q": term, "offset": 0, "count": GROUP_SIZE}

# make the search
print("[INFO] searching Bing API for '{}'".format(term))
search = requests.get(URL, headers=headers, params=params)
search.raise_for_status()

# grab the results from the search, including the total number of
# estimated results returned by the Bing API
results = search.json()
estNumResults = min(results["totalEstimatedMatches"], MAX_RESULTS)
print("[INFO] {} total results for '{}'".format(estNumResults, term))

# initialize the total number of images downloaded thus far
total = 0


def grab_page(url, ext, total):

    try:
        # total += 1
        print("[INFO] fetching: {}".format(url))
        r = requests.get(url, timeout=30)
        # build the path to the output image

        #here total is only for filename creation
        p = os.path.sep.join([output, "{}{}".format(
            str(total).zfill(8), ext)])

        # write the image to disk
        f = open(p, "wb")
        f.write(r.content)
        f.close()

        # try to load the image from disk
        image = cv2.imread(p)

        # if the image is None then we could not properly load the
        # image from disk (so it should be ignored)
        if image is None:
            print("[INFO] deleting: {}".format(p))
            os.remove(p)
            return

    # catch any errors that would not unable us to download the
    # image
    except Exception as e:
        # check to see if our exception is in our list of
        # exceptions to check for
        if type(e) in EXCEPTIONS:
            print("[INFO] skipping: {}".format(url))
            return

# loop over the estimated number of results in GROUP_SIZE groups
for offset in range(0, estNumResults, GROUP_SIZE):
    # update the search parameters using the current offset, then
    # make the request to fetch the results
    print("[INFO] making request for group {}-{} of {}...".format(
        offset, offset + GROUP_SIZE, estNumResults))
    params["offset"] = offset
    search = requests.get(URL, headers=headers, params=params)
    search.raise_for_status()
    results = search.json()
    print("[INFO] saving images for group {}-{} of {}...".format(
        offset, offset + GROUP_SIZE, estNumResults))
    # loop over the results
    jobs = []
    for v in results["value"]:
        total += 1
        ext = v["contentUrl"][v["contentUrl"].rfind("."):]
        url = v["contentUrl"]
        
        # create gevent job
        jobs.append(gevent.spawn(grab_page, url, ext, total))

    # wait for all jobs to complete
    gevent.joinall(jobs, timeout=10)
    print(total)
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# [INFO] searching Bing API for 'Gengar'
# [INFO] 250 total results for 'Gengar'
# [INFO] making request for group 0-50 of 250...
# [INFO] saving images for group 0-50 of 250...
# [INFO] fetching: https://img.pokemondb.net/artwork/gengar.jpg
# [INFO] skipping: https://img.pokemondb.net/artwork/gengar.jpg
# [INFO] fetching: https://static.pokemonpets.com/images/monsters-images-800-800/94-Gengar.png
# [INFO] skipping: https://static.pokemonpets.com/images/monsters-images-800-800/94-Gengar.png
# [INFO] fetching: http://ovicio.com.br/wp-content/uploads/gengar1.png
# [INFO] skipping: http://ovicio.com.br/wp-content/uploads/gengar1.png
# [INFO] fetching: https://img.pokemondb.net/artwork/large/gengar-mega.jpg
# [INFO] skipping: https://img.pokemondb.net/artwork/large/gengar-mega.jpg
# [INFO] fetching: http://static.pokemonpets.com/images/monsters-images-800-800/2094-Shiny-Gengar.png
# [INFO] skipping: http://static.pokemonpets.com/images/monsters-images-800-800/2094-Shiny-Gengar.png
# [INFO] fetching: http://th01.deviantart.net/fs71/PRE/i/2012/279/2/2/gengar_by_bloodyakuma93-d5gy4xw.png
# [INFO] skipping: http://th01.deviantart.net/fs71/PRE/i/2012/279/2/2/gengar_by_bloodyakuma93-d5gy4xw.png
# [INFO] fetching: http://4.bp.blogspot.com/-P6pXYJrouxE/VkNrVPqzQjI/AAAAAAAABuE/L0_2yUAHb9Y/s1600/gastly__haunter_and_gengar_by_ninjendo-d6uul44.png
# [INFO] skipping: http://4.bp.blogspot.com/-P6pXYJrouxE/VkNrVPqzQjI/AAAAAAAABuE/L0_2yUAHb9Y/s1600/gastly__haunter_and_gengar_by_ninjendo-d6uul44.png
# [INFO] fetching: http://24.media.tumblr.com/2c76ed3cb5c9dc6c062b0ea18ac5cae4/tumblr_mi46pggXjd1rk9plqo1_500.png
# [INFO] skipping: http://24.media.tumblr.com/2c76ed3cb5c9dc6c062b0ea18ac5cae4/tumblr_mi46pggXjd1rk9plqo1_500.png
# [INFO] fetching: http://th07.deviantart.net/fs71/PRE/i/2013/259/d/b/_94_gengar_by_jackspade2012-d6jjpjx.png
# [INFO] skipping: http://th07.deviantart.net/fs71/PRE/i/2013/259/d/b/_94_gengar_by_jackspade2012-d6jjpjx.png
# [INFO] fetching: http://cdn.bulbagarden.net/upload/b/b9/Pokk%C3%A9n_Gengar.png
# [INFO] skipping: http://cdn.bulbagarden.net/upload/b/b9/Pokk%C3%A9n_Gengar.png
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/a7/43/ee/a743eed0c503ae6a639f8fe564370587.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/a7/43/ee/a743eed0c503ae6a639f8fe564370587.jpg
# [INFO] fetching: http://fc07.deviantart.net/fs50/f/2009/332/b/4/Gengar_Shadow_Ball_by_Scootw91.jpg
# [INFO] skipping: http://fc07.deviantart.net/fs50/f/2009/332/b/4/Gengar_Shadow_Ball_by_Scootw91.jpg
# [INFO] fetching: https://mahoutofu.files.wordpress.com/2013/11/gengar.png
# [INFO] skipping: https://mahoutofu.files.wordpress.com/2013/11/gengar.png
# [INFO] fetching: http://img2.wikia.nocookie.net/__cb20150821061201/pokemon/images/e/e9/Fantina_Gengar.png
# [INFO] skipping: http://img2.wikia.nocookie.net/__cb20150821061201/pokemon/images/e/e9/Fantina_Gengar.png
# [INFO] fetching: http://orig11.deviantart.net/3475/f/2012/015/0/f/gengar_the_shadow_pokemon_by_gengargrin-d4mf2te.jpg
# [INFO] skipping: http://orig11.deviantart.net/3475/f/2012/015/0/f/gengar_the_shadow_pokemon_by_gengargrin-d4mf2te.jpg
# [INFO] fetching: https://www.technobuffalo.com/wp-content/uploads/2014/09/Shiny-Gengar-1.jpg
# [INFO] skipping: https://www.technobuffalo.com/wp-content/uploads/2014/09/Shiny-Gengar-1.jpg
# [INFO] fetching: https://res.cloudinary.com/teepublic/image/private/s--JPF23pLf--/t_Preview/b_rgb:191919,c_limit,f_jpg,h_630,q_90,w_630/v1454101384/production/designs/407032_1.jpg
# [INFO] skipping: https://res.cloudinary.com/teepublic/image/private/s--JPF23pLf--/t_Preview/b_rgb:191919,c_limit,f_jpg,h_630,q_90,w_630/v1454101384/production/designs/407032_1.jpg
# [INFO] fetching: https://thehiddenchest.files.wordpress.com/2014/10/gengar.png
# [INFO] skipping: https://thehiddenchest.files.wordpress.com/2014/10/gengar.png
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/originals/95/38/09/95380979d61e37747dc903bd0c9c226e.png
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/originals/95/38/09/95380979d61e37747dc903bd0c9c226e.png
# [INFO] fetching: http://www.smogon.com/articles/images/gengar-through-ages.png
# [INFO] skipping: http://www.smogon.com/articles/images/gengar-through-ages.png
# [INFO] fetching: https://cdn.wallpapersafari.com/25/72/dmoATN.png
# [INFO] skipping: https://cdn.wallpapersafari.com/25/72/dmoATN.png
# [INFO] fetching: http://fc05.deviantart.net/fs70/i/2013/206/0/5/gengar_commission_by_ashteritops-d6f02bc.png
# [INFO] skipping: http://fc05.deviantart.net/fs70/i/2013/206/0/5/gengar_commission_by_ashteritops-d6f02bc.png
# [INFO] fetching: http://orig04.deviantart.net/e881/f/2015/026/f/1/gengar___the_shadow_pokemon___redo__by_realscyler-d8fhqc3.png
# [INFO] skipping: http://orig04.deviantart.net/e881/f/2015/026/f/1/gengar___the_shadow_pokemon___redo__by_realscyler-d8fhqc3.png
# [INFO] fetching: https://www.technobuffalo.com/wp-content/uploads/2015/04/Gengar-Pokemon.jpg
# [INFO] skipping: https://www.technobuffalo.com/wp-content/uploads/2015/04/Gengar-Pokemon.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/83/80/95/8380952276c43579e34aa59e730598ca.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/83/80/95/8380952276c43579e34aa59e730598ca.jpg
# [INFO] fetching: http://fc06.deviantart.net/fs71/i/2013/291/9/e/mega_gengar_by_sparkru_chan-d6qy8yl.png
# [INFO] skipping: http://fc06.deviantart.net/fs71/i/2013/291/9/e/mega_gengar_by_sparkru_chan-d6qy8yl.png
# [INFO] fetching: http://th02.deviantart.net/fs70/PRE/f/2013/081/e/6/gengar___nightmare_by_ishmam-d5ywclo.png
# [INFO] skipping: http://th02.deviantart.net/fs70/PRE/f/2013/081/e/6/gengar___nightmare_by_ishmam-d5ywclo.png
# [INFO] fetching: http://static.fjcdn.com/large/pictures/fb/ec/fbec60_234509.jpg
# [INFO] skipping: http://static.fjcdn.com/large/pictures/fb/ec/fbec60_234509.jpg
# [INFO] fetching: http://www.thinkgeek.com/images/products/zoom/jupq_gengar_plush.jpg
# [INFO] skipping: http://www.thinkgeek.com/images/products/zoom/jupq_gengar_plush.jpg
# [INFO] fetching: http://25.media.tumblr.com/tumblr_mdgswdraT81r46py4o1_1280.jpg
# [INFO] skipping: http://25.media.tumblr.com/tumblr_mdgswdraT81r46py4o1_1280.jpg
# [INFO] fetching: http://3.bp.blogspot.com/-ToW3GHRvKXo/T6X7O1dRPYI/AAAAAAAANtU/bEQsqcmdgQY/s1600/094+pokmeon+blue+gengar.gif
# [INFO] skipping: http://3.bp.blogspot.com/-ToW3GHRvKXo/T6X7O1dRPYI/AAAAAAAANtU/bEQsqcmdgQY/s1600/094+pokmeon+blue+gengar.gif
# [INFO] fetching: http://vignette1.wikia.nocookie.net/pokemon/images/7/7e/Agatha_Gengar_Generations.png/revision/latest?cb=20160923174818
# [INFO] skipping: http://vignette1.wikia.nocookie.net/pokemon/images/7/7e/Agatha_Gengar_Generations.png/revision/latest?cb=20160923174818
# [INFO] fetching: http://img03.deviantart.net/cba1/i/2016/169/9/5/gengar___nightmare_by_ishmam-d5ywclo.png
# [INFO] skipping: http://img03.deviantart.net/cba1/i/2016/169/9/5/gengar___nightmare_by_ishmam-d5ywclo.png
# [INFO] fetching: http://pm1.narvii.com/5999/d9f7d2165f6542f9a95ac4212085e5b2b490fa71_hq.jpg
# [INFO] skipping: http://pm1.narvii.com/5999/d9f7d2165f6542f9a95ac4212085e5b2b490fa71_hq.jpg
# [INFO] fetching: http://i.kinja-img.com/gawker-media/image/upload/t_original/habdp7lubx3aln3ud2qv.png
# [INFO] skipping: http://i.kinja-img.com/gawker-media/image/upload/t_original/habdp7lubx3aln3ud2qv.png
# [INFO] fetching: http://img11.deviantart.net/07f5/i/2013/324/9/6/gengar_by_theemerald-d6uzv1l.png
# [INFO] skipping: http://img11.deviantart.net/07f5/i/2013/324/9/6/gengar_by_theemerald-d6uzv1l.png
# [INFO] fetching: https://yt3.ggpht.com/-ebE-rDC9ORk/AAAAAAAAAAI/AAAAAAAAAAA/vamW7r8aDmw/s900-c-k-no-mo-rj-c0xffffff/photo.jpg
# [INFO] skipping: https://yt3.ggpht.com/-ebE-rDC9ORk/AAAAAAAAAAI/AAAAAAAAAAA/vamW7r8aDmw/s900-c-k-no-mo-rj-c0xffffff/photo.jpg
# [INFO] fetching: http://pre05.deviantart.net/5dc6/th/pre/i/2013/097/d/8/gengar___by_murkis8888-d60r0wh.png
# [INFO] skipping: http://pre05.deviantart.net/5dc6/th/pre/i/2013/097/d/8/gengar___by_murkis8888-d60r0wh.png
# [INFO] fetching: http://img1.wikia.nocookie.net/__cb20110928113845/pokemon/images/c/ce/Drake_Gengar.png
# [INFO] skipping: http://img1.wikia.nocookie.net/__cb20110928113845/pokemon/images/c/ce/Drake_Gengar.png
# [INFO] fetching: http://vignette3.wikia.nocookie.net/pokemon/images/b/bd/Gengar_IL023.png/revision/latest?cb=20150607165031
# [INFO] skipping: http://vignette3.wikia.nocookie.net/pokemon/images/b/bd/Gengar_IL023.png/revision/latest?cb=20150607165031
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/b7/10/50/b7105053330f29252652fe66f992c919.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/b7/10/50/b7105053330f29252652fe66f992c919.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/e1/d0/15/e1d015f309a1b7883f9b383bef6f04e9.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/e1/d0/15/e1d015f309a1b7883f9b383bef6f04e9.jpg
# [INFO] fetching: http://vignette4.wikia.nocookie.net/pokemon/images/6/62/Agatha_Gengar_anime.png/revision/latest?cb=20150821060924
# [INFO] skipping: http://vignette4.wikia.nocookie.net/pokemon/images/6/62/Agatha_Gengar_anime.png/revision/latest?cb=20150821060924
# [INFO] fetching: https://i.pinimg.com/736x/16/20/70/1620708a19fa2fbe853fc34bda330438--ghost-pokemon--pokemon.jpg
# [INFO] skipping: https://i.pinimg.com/736x/16/20/70/1620708a19fa2fbe853fc34bda330438--ghost-pokemon--pokemon.jpg
# [INFO] fetching: https://cdn.wallpapersafari.com/44/47/nS0kXW.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/44/47/nS0kXW.jpg
# [INFO] fetching: http://vignette2.wikia.nocookie.net/pokemon/images/6/62/Conley_Gengar.png/revision/latest?cb=20151021055834
# [INFO] skipping: http://vignette2.wikia.nocookie.net/pokemon/images/6/62/Conley_Gengar.png/revision/latest?cb=20151021055834
# [INFO] fetching: https://i.pinimg.com/736x/f7/c5/cc/f7c5ccce479660597fb0bc122df0e917--cool-pokemon-ghost-pokemon.jpg
# [INFO] skipping: https://i.pinimg.com/736x/f7/c5/cc/f7c5ccce479660597fb0bc122df0e917--cool-pokemon-ghost-pokemon.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/88/99/14/889914020cc5a8aaaec775cb00a24288.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/88/99/14/889914020cc5a8aaaec775cb00a24288.jpg
# [INFO] fetching: http://cdn.wallpapersafari.com/15/47/d5MTZk.png
# [INFO] skipping: http://cdn.wallpapersafari.com/15/47/d5MTZk.png
# [INFO] fetching: http://fc03.deviantart.net/fs71/f/2010/099/2/d/Gengar_Wallpaper_by_Victor_Sama.png
# [INFO] skipping: http://fc03.deviantart.net/fs71/f/2010/099/2/d/Gengar_Wallpaper_by_Victor_Sama.png
# 50
# [INFO] making request for group 50-100 of 250...
# [INFO] saving images for group 50-100 of 250...
# [INFO] fetching: http://pm1.narvii.com/5999/d9f7d2165f6542f9a95ac4212085e5b2b490fa71_hq.jpg
# [INFO] skipping: http://pm1.narvii.com/5999/d9f7d2165f6542f9a95ac4212085e5b2b490fa71_hq.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/88/99/14/889914020cc5a8aaaec775cb00a24288.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/88/99/14/889914020cc5a8aaaec775cb00a24288.jpg
# [INFO] fetching: http://static.fjcdn.com/large/pictures/fb/ec/fbec60_234509.jpg
# [INFO] skipping: http://static.fjcdn.com/large/pictures/fb/ec/fbec60_234509.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/e1/d0/15/e1d015f309a1b7883f9b383bef6f04e9.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/e1/d0/15/e1d015f309a1b7883f9b383bef6f04e9.jpg
# [INFO] fetching: http://img11.deviantart.net/07f5/i/2013/324/9/6/gengar_by_theemerald-d6uzv1l.png
# [INFO] skipping: http://img11.deviantart.net/07f5/i/2013/324/9/6/gengar_by_theemerald-d6uzv1l.png
# [INFO] fetching: http://3.bp.blogspot.com/-ToW3GHRvKXo/T6X7O1dRPYI/AAAAAAAANtU/bEQsqcmdgQY/s1600/094+pokmeon+blue+gengar.gif
# [INFO] skipping: http://3.bp.blogspot.com/-ToW3GHRvKXo/T6X7O1dRPYI/AAAAAAAANtU/bEQsqcmdgQY/s1600/094+pokmeon+blue+gengar.gif
# [INFO] fetching: http://vignette3.wikia.nocookie.net/pokemon/images/b/bd/Gengar_IL023.png/revision/latest?cb=20150607165031
# [INFO] skipping: http://vignette3.wikia.nocookie.net/pokemon/images/b/bd/Gengar_IL023.png/revision/latest?cb=20150607165031
# [INFO] fetching: https://i.pinimg.com/736x/16/20/70/1620708a19fa2fbe853fc34bda330438--ghost-pokemon--pokemon.jpg
# [INFO] skipping: https://i.pinimg.com/736x/16/20/70/1620708a19fa2fbe853fc34bda330438--ghost-pokemon--pokemon.jpg
# [INFO] fetching: http://www.thinkgeek.com/images/products/zoom/jupq_gengar_plush.jpg
# [INFO] skipping: http://www.thinkgeek.com/images/products/zoom/jupq_gengar_plush.jpg
# [INFO] fetching: http://orig13.deviantart.net/167c/f/2013/338/6/9/realistic_pokemon__gengar_by_renecampbellart-d61werl.jpg
# [INFO] skipping: http://orig13.deviantart.net/167c/f/2013/338/6/9/realistic_pokemon__gengar_by_renecampbellart-d61werl.jpg
# [INFO] fetching: http://fc01.deviantart.net/fs71/f/2012/206/0/4/gengar_by_causeimdanjones-d58k2wr.jpg
# [INFO] skipping: http://fc01.deviantart.net/fs71/f/2012/206/0/4/gengar_by_causeimdanjones-d58k2wr.jpg
# [INFO] fetching: https://allthingsdantastic.files.wordpress.com/2016/02/wp-1456613488102.jpg
# [INFO] skipping: https://allthingsdantastic.files.wordpress.com/2016/02/wp-1456613488102.jpg
# [INFO] fetching: http://pre11.deviantart.net/d875/th/pre/f/2016/306/b/7/gengar_by_joelchan-dan1jq3.jpg
# [INFO] skipping: http://pre11.deviantart.net/d875/th/pre/f/2016/306/b/7/gengar_by_joelchan-dan1jq3.jpg
# [INFO] fetching: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2311/701-00276/P2311_701-00276_01.jpg
# [INFO] skipping: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2311/701-00276/P2311_701-00276_01.jpg
# [INFO] fetching: http://orig08.deviantart.net/8d72/f/2013/324/3/1/free_gengar_pokemon_vector_by_emerald_stock-d6uzx2c.png
# [INFO] skipping: http://orig08.deviantart.net/8d72/f/2013/324/3/1/free_gengar_pokemon_vector_by_emerald_stock-d6uzx2c.png
# [INFO] fetching: http://vignette2.wikia.nocookie.net/pokemon/images/6/62/Conley_Gengar.png/revision/latest?cb=20151021055834
# [INFO] skipping: http://vignette2.wikia.nocookie.net/pokemon/images/6/62/Conley_Gengar.png/revision/latest?cb=20151021055834
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/22/00/08/220008dfd211a1a324639a967fc16fe1.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/22/00/08/220008dfd211a1a324639a967fc16fe1.jpg
# [INFO] fetching: https://www.technobuffalo.com/wp-content/uploads/2016/07/Gengar.jpg
# [INFO] skipping: https://www.technobuffalo.com/wp-content/uploads/2016/07/Gengar.jpg
# [INFO] fetching: http://fc07.deviantart.net/fs70/i/2012/145/e/7/gengar_by_m_thirteen-d514cmr.jpg
# [INFO] skipping: http://fc07.deviantart.net/fs70/i/2012/145/e/7/gengar_by_m_thirteen-d514cmr.jpg
# [INFO] fetching: http://img13.deviantart.net/aeec/i/2012/363/5/2/nightmare__gengar_minimal__pokemon__by_ruwah-d5plc61.jpg
# [INFO] skipping: http://img13.deviantart.net/aeec/i/2012/363/5/2/nightmare__gengar_minimal__pokemon__by_ruwah-d5plc61.jpg
# [INFO] fetching: https://i.pinimg.com/736x/f7/c5/cc/f7c5ccce479660597fb0bc122df0e917--cool-pokemon-ghost-pokemon.jpg
# [INFO] skipping: https://i.pinimg.com/736x/f7/c5/cc/f7c5ccce479660597fb0bc122df0e917--cool-pokemon-ghost-pokemon.jpg
# [INFO] fetching: https://cdn.wallpapersafari.com/44/47/nS0kXW.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/44/47/nS0kXW.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/fd/56/5e/fd565e4e62eb6e35a69fdd9140c06a8f.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/fd/56/5e/fd565e4e62eb6e35a69fdd9140c06a8f.jpg
# [INFO] fetching: http://cdn.wallpapersafari.com/15/47/d5MTZk.png
# [INFO] skipping: http://cdn.wallpapersafari.com/15/47/d5MTZk.png
# [INFO] fetching: https://pokewalls.files.wordpress.com/2013/06/94gengar1920x1080.jpg
# [INFO] skipping: https://pokewalls.files.wordpress.com/2013/06/94gengar1920x1080.jpg
# [INFO] fetching: https://pm1.narvii.com/6566/3f5168b63c74f72e928c837c2171773bab6115da_hq.jpg
# [INFO] skipping: https://pm1.narvii.com/6566/3f5168b63c74f72e928c837c2171773bab6115da_hq.jpg
# [INFO] fetching: https://geekbeerz.files.wordpress.com/2014/11/gengar.png
# [INFO] skipping: https://geekbeerz.files.wordpress.com/2014/11/gengar.png
# [INFO] fetching: https://cdn.weasyl.com/~bloodlordskonia/submissions/1327130/5c1c0c99f05b596a0911dd843cc46501290e42b71c914ac4efb40331607a94fc/bloodlordskonia-mega-gengar.png
# [INFO] skipping: https://cdn.weasyl.com/~bloodlordskonia/submissions/1327130/5c1c0c99f05b596a0911dd843cc46501290e42b71c914ac4efb40331607a94fc/bloodlordskonia-mega-gengar.png
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/originals/6f/2a/37/6f2a37a6507369ae1e6da33630920480.png
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/originals/6f/2a/37/6f2a37a6507369ae1e6da33630920480.png
# [INFO] fetching: https://image.redbull.com/rbcom/010/2017-03-24/1331850806234_2/0100/0/1/yep-gengar-used-to-be-a-human..jpg
# [INFO] skipping: https://image.redbull.com/rbcom/010/2017-03-24/1331850806234_2/0100/0/1/yep-gengar-used-to-be-a-human..jpg
# [INFO] fetching: https://res.cloudinary.com/teepublic/image/private/s--b1olNsTU--/t_Preview/b_rgb:191919,c_limit,f_jpg,h_630,q_90,w_630/v1446158264/production/designs/52608_0.jpg
# [INFO] skipping: https://res.cloudinary.com/teepublic/image/private/s--b1olNsTU--/t_Preview/b_rgb:191919,c_limit,f_jpg,h_630,q_90,w_630/v1446158264/production/designs/52608_0.jpg
# [INFO] fetching: https://i.pinimg.com/736x/f5/bd/ae/f5bdaed97c475ce08fc63dcb942a4249--gengar-pokemon-pokemon-fan.jpg
# [INFO] skipping: https://i.pinimg.com/736x/f5/bd/ae/f5bdaed97c475ce08fc63dcb942a4249--gengar-pokemon-pokemon-fan.jpg
# [INFO] fetching: http://static.zerochan.net/Gengar.full.1735040.jpg
# [INFO] skipping: http://static.zerochan.net/Gengar.full.1735040.jpg
# [INFO] fetching: http://pre01.deviantart.net/3618/th/pre/i/2015/249/2/9/greninja_and_gengar_discover_the_internet__video__by_liberlibelula-d8u1nq4.jpg
# [INFO] skipping: http://pre01.deviantart.net/3618/th/pre/i/2015/249/2/9/greninja_and_gengar_discover_the_internet__video__by_liberlibelula-d8u1nq4.jpg
# [INFO] fetching: https://orig00.deviantart.net/a062/f/2016/021/9/0/gengar_by_mintenndo-d9orl8z.png
# [INFO] skipping: https://orig00.deviantart.net/a062/f/2016/021/9/0/gengar_by_mintenndo-d9orl8z.png
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/dc/a1/4d/dca14dc08de18231c68fcefde22600bd.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/dc/a1/4d/dca14dc08de18231c68fcefde22600bd.jpg
# [INFO] fetching: http://fc02.deviantart.net/fs70/f/2011/161/a/1/gengar__sketch__by_blastertwo-d3ikphf.png
# [INFO] skipping: http://fc02.deviantart.net/fs70/f/2011/161/a/1/gengar__sketch__by_blastertwo-d3ikphf.png
# [INFO] fetching: http://guidesmedia.ign.com/guides/059687/images/blackwhite/pokemans_094.gif
# [INFO] skipping: http://guidesmedia.ign.com/guides/059687/images/blackwhite/pokemans_094.gif
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/b0/45/b0/b045b0a66c2b8263932fed120eb3eb8f--pokemon-p-ghost-pokemon.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/b0/45/b0/b045b0a66c2b8263932fed120eb3eb8f--pokemon-p-ghost-pokemon.jpg
# [INFO] fetching: https://vignette4.wikia.nocookie.net/pokemon/images/e/eb/Team_Meanies_Gengar.png/revision/latest?cb=20150806043746
# [INFO] skipping: https://vignette4.wikia.nocookie.net/pokemon/images/e/eb/Team_Meanies_Gengar.png/revision/latest?cb=20150806043746
# [INFO] fetching: http://orig08.deviantart.net/d41f/f/2015/084/c/f/mega_gengar_wallpaper__big_face__by_theshinyfurfrou-d8n1o32.png
# [INFO] skipping: http://orig08.deviantart.net/d41f/f/2015/084/c/f/mega_gengar_wallpaper__big_face__by_theshinyfurfrou-d8n1o32.png
# [INFO] fetching: http://fc03.deviantart.net/fs71/f/2010/099/2/d/Gengar_Wallpaper_by_Victor_Sama.png
# [INFO] skipping: http://fc03.deviantart.net/fs71/f/2010/099/2/d/Gengar_Wallpaper_by_Victor_Sama.png
# [INFO] fetching: http://pokecharms.com/data/attachment-files/2015/06/199794_MEGA_GENGAR.png
# [INFO] skipping: http://pokecharms.com/data/attachment-files/2015/06/199794_MEGA_GENGAR.png
# [INFO] fetching: https://vignette1.wikia.nocookie.net/pokemon/images/1/18/Jarvis%27_Gengar.png/revision/latest?cb=20161221042757
# [INFO] skipping: https://vignette1.wikia.nocookie.net/pokemon/images/1/18/Jarvis%27_Gengar.png/revision/latest?cb=20161221042757
# [INFO] fetching: https://static.zerochan.net/Gengar.full.2056784.jpg
# [INFO] skipping: https://static.zerochan.net/Gengar.full.2056784.jpg
# [INFO] fetching: https://i.pinimg.com/736x/b7/e7/03/b7e7038b2d8a5f69f73aff3f8287958e--wallpaper-iphone-pokemon.jpg
# [INFO] skipping: https://i.pinimg.com/736x/b7/e7/03/b7e7038b2d8a5f69f73aff3f8287958e--wallpaper-iphone-pokemon.jpg
# [INFO] fetching: https://i.ytimg.com/vi/Bzdn22JUVm0/maxresdefault.jpg
# [INFO] skipping: https://i.ytimg.com/vi/Bzdn22JUVm0/maxresdefault.jpg
# [INFO] fetching: https://i.pinimg.com/originals/a2/30/98/a230988666171afd78555b3782cc74ad.jpg
# [INFO] skipping: https://i.pinimg.com/originals/a2/30/98/a230988666171afd78555b3782cc74ad.jpg
# [INFO] fetching: http://pre05.deviantart.net/6441/th/pre/i/2016/108/1/d/gengar_by_varied_artist-d9zf1dn.png
# [INFO] skipping: http://pre05.deviantart.net/6441/th/pre/i/2016/108/1/d/gengar_by_varied_artist-d9zf1dn.png
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/13/80/c7/1380c77cc52856bcf9c5df35020b1789.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/13/80/c7/1380c77cc52856bcf9c5df35020b1789.jpg
# 100
# [INFO] making request for group 100-150 of 250...
# [INFO] saving images for group 100-150 of 250...
# [INFO] fetching: https://geekbeerz.files.wordpress.com/2014/11/gengar.png
# [INFO] skipping: https://geekbeerz.files.wordpress.com/2014/11/gengar.png
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/b0/45/b0/b045b0a66c2b8263932fed120eb3eb8f--pokemon-p-ghost-pokemon.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/b0/45/b0/b045b0a66c2b8263932fed120eb3eb8f--pokemon-p-ghost-pokemon.jpg
# [INFO] fetching: https://vignette1.wikia.nocookie.net/pokemon/images/1/18/Jarvis%27_Gengar.png/revision/latest?cb=20161221042757
# [INFO] skipping: https://vignette1.wikia.nocookie.net/pokemon/images/1/18/Jarvis%27_Gengar.png/revision/latest?cb=20161221042757
# [INFO] fetching: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P3520/701-02858/P3520_701-02858_01.jpg
# [INFO] skipping: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P3520/701-02858/P3520_701-02858_01.jpg
# [INFO] fetching: http://getwallpapers.com/wallpaper/full/7/4/7/323689.jpg
# [INFO] skipping: http://getwallpapers.com/wallpaper/full/7/4/7/323689.jpg
# [INFO] fetching: https://i.pinimg.com/originals/a2/30/98/a230988666171afd78555b3782cc74ad.jpg
# [INFO] skipping: https://i.pinimg.com/originals/a2/30/98/a230988666171afd78555b3782cc74ad.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/dc/a1/4d/dca14dc08de18231c68fcefde22600bd.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/dc/a1/4d/dca14dc08de18231c68fcefde22600bd.jpg
# [INFO] fetching: http://fc00.deviantart.net/fs70/f/2012/009/1/9/gengar_pokemon_rby_by_kakashii182-d4lsn5b.png
# [INFO] skipping: http://fc00.deviantart.net/fs70/f/2012/009/1/9/gengar_pokemon_rby_by_kakashii182-d4lsn5b.png
# [INFO] fetching: http://pre05.deviantart.net/6441/th/pre/i/2016/108/1/d/gengar_by_varied_artist-d9zf1dn.png
# [INFO] skipping: http://pre05.deviantart.net/6441/th/pre/i/2016/108/1/d/gengar_by_varied_artist-d9zf1dn.png
# [INFO] fetching: http://mm.blogsport.de/images/clefable_gengar.png
# [INFO] skipping: http://mm.blogsport.de/images/clefable_gengar.png
# [INFO] fetching: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P4514/710-03475/P4514_710-03475_01.jpg
# [INFO] skipping: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P4514/710-03475/P4514_710-03475_01.jpg
# [INFO] fetching: http://pokecharms.com/data/attachment-files/2015/06/199794_MEGA_GENGAR.png
# [INFO] skipping: http://pokecharms.com/data/attachment-files/2015/06/199794_MEGA_GENGAR.png
# [INFO] fetching: https://vignette4.wikia.nocookie.net/pokemon/images/e/eb/Team_Meanies_Gengar.png/revision/latest?cb=20150806043746
# [INFO] skipping: https://vignette4.wikia.nocookie.net/pokemon/images/e/eb/Team_Meanies_Gengar.png/revision/latest?cb=20150806043746
# [INFO] fetching: https://i.ytimg.com/vi/Bzdn22JUVm0/maxresdefault.jpg
# [INFO] skipping: https://i.ytimg.com/vi/Bzdn22JUVm0/maxresdefault.jpg
# [INFO] fetching: https://gonintendo.com/system/file_uploads/uploads/000/048/305/original/P4122_703-02991_01.jpg
# [INFO] skipping: https://gonintendo.com/system/file_uploads/uploads/000/048/305/original/P4122_703-02991_01.jpg
# [INFO] fetching: http://comicsalliance.com/files/2013/02/illustration.jpg
# [INFO] skipping: http://comicsalliance.com/files/2013/02/illustration.jpg
# [INFO] fetching: https://static.zerochan.net/Gengar.full.2056784.jpg
# [INFO] skipping: https://static.zerochan.net/Gengar.full.2056784.jpg
# [INFO] fetching: https://d.wattpad.com/story_parts/38/images/1415de2aba7ae1fb.jpg
# [INFO] skipping: https://d.wattpad.com/story_parts/38/images/1415de2aba7ae1fb.jpg
# [INFO] fetching: https://www.gamerebel.net/wp-content/uploads/2015/08/Gengar.jpg
# [INFO] skipping: https://www.gamerebel.net/wp-content/uploads/2015/08/Gengar.jpg
# [INFO] fetching: https://i.pinimg.com/736x/b7/e7/03/b7e7038b2d8a5f69f73aff3f8287958e--wallpaper-iphone-pokemon.jpg
# [INFO] skipping: https://i.pinimg.com/736x/b7/e7/03/b7e7038b2d8a5f69f73aff3f8287958e--wallpaper-iphone-pokemon.jpg
# [INFO] fetching: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P1583/701-00484/P1583_701-00484_01.jpg
# [INFO] skipping: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P1583/701-00484/P1583_701-00484_01.jpg
# [INFO] fetching: https://www.weasyl.com/~nukeleer/submissions/532220/a8f39a78c2a1ee30505e378853f09ea411b2e0d1684caff4c7c62095ab4a097d/nukeleer-gengar-and-crobat.png
# [INFO] skipping: https://www.weasyl.com/~nukeleer/submissions/532220/a8f39a78c2a1ee30505e378853f09ea411b2e0d1684caff4c7c62095ab4a097d/nukeleer-gengar-and-crobat.png
# [INFO] fetching: http://images2.fanpop.com/images/photos/2800000/Gengar-pokemon-2833232-1200-870.jpg
# [INFO] skipping: http://images2.fanpop.com/images/photos/2800000/Gengar-pokemon-2833232-1200-870.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/13/80/c7/1380c77cc52856bcf9c5df35020b1789.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/13/80/c7/1380c77cc52856bcf9c5df35020b1789.jpg
# [INFO] fetching: http://assets2.ignimgs.com/2015/04/26/pokken-gengar-02jpg-487bbc_1280w.jpg
# [INFO] skipping: http://assets2.ignimgs.com/2015/04/26/pokken-gengar-02jpg-487bbc_1280w.jpg
# [INFO] fetching: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-HD-Wallpaper.jpg
# [INFO] skipping: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-HD-Wallpaper.jpg
# [INFO] fetching: https://orig00.deviantart.net/747c/f/2017/174/5/9/mega_gengar_by_booksweetdoodle-dbdsdyn.png
# [INFO] skipping: https://orig00.deviantart.net/747c/f/2017/174/5/9/mega_gengar_by_booksweetdoodle-dbdsdyn.png
# [INFO] fetching: https://static.zerochan.net/Gengar.full.1606040.jpg
# [INFO] skipping: https://static.zerochan.net/Gengar.full.1606040.jpg
# [INFO] fetching: http://pm1.narvii.com/5762/ca76915dfe479418aca789d4cab5f2a102321e7f_hq.jpg
# [INFO] skipping: http://pm1.narvii.com/5762/ca76915dfe479418aca789d4cab5f2a102321e7f_hq.jpg
# [INFO] fetching: https://art.ngfiles.com/images/227000/227592_mario644_gengar.png?f1355151354
# [INFO] skipping: https://art.ngfiles.com/images/227000/227592_mario644_gengar.png?f1355151354
# [INFO] fetching: https://i.pinimg.com/originals/12/05/b4/1205b47f6ebb8a3f10a574a2d2eccaf7.jpg
# [INFO] skipping: https://i.pinimg.com/originals/12/05/b4/1205b47f6ebb8a3f10a574a2d2eccaf7.jpg
# [INFO] fetching: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-Wallpapers-HD.jpg
# [INFO] skipping: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-Wallpapers-HD.jpg
# [INFO] fetching: https://i.pinimg.com/736x/ec/6e/6c/ec6e6c4f3f6bbbbdb70988d4bbb6b24d--charmeleon-pokemon-yahoo-search.jpg
# [INFO] skipping: https://i.pinimg.com/736x/ec/6e/6c/ec6e6c4f3f6bbbbdb70988d4bbb6b24d--charmeleon-pokemon-yahoo-search.jpg
# [INFO] fetching: http://wallpapercave.com/wp/G5u5K3P.png
# [INFO] skipping: http://wallpapercave.com/wp/G5u5K3P.png
# [INFO] fetching: https://nintendoeverything.com/wp-content/uploads/gengar.png
# [INFO] skipping: https://nintendoeverything.com/wp-content/uploads/gengar.png
# [INFO] fetching: https://cdn.wallpapersafari.com/10/25/EiP5r3.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/10/25/EiP5r3.jpg
# [INFO] fetching: https://cdn.weasyl.com/~ijdraws/submissions/1150377/02a6a7fc79de66010bb771bbaccabea2a9b4a9f19c9272e416fb5d0fc1d411c1/ijdraws-gengar.png
# [INFO] skipping: https://cdn.weasyl.com/~ijdraws/submissions/1150377/02a6a7fc79de66010bb771bbaccabea2a9b4a9f19c9272e416fb5d0fc1d411c1/ijdraws-gengar.png
# [INFO] fetching: https://ae01.alicdn.com/kf/HTB1MrrJcFmWBuNjSspdq6zugXXa9/1Piece-Pokemon-Inspired-LED-Wall-Light-Remote-Activated-Gengar-Pokemon-LED-Backlit-Wall-Art-Color-Changing.jpg
# [INFO] skipping: https://ae01.alicdn.com/kf/HTB1MrrJcFmWBuNjSspdq6zugXXa9/1Piece-Pokemon-Inspired-LED-Wall-Light-Remote-Activated-Gengar-Pokemon-LED-Backlit-Wall-Art-Color-Changing.jpg
# [INFO] fetching: https://static.zerochan.net/Gengar.full.781311.jpg
# [INFO] skipping: https://static.zerochan.net/Gengar.full.781311.jpg
# [INFO] fetching: http://th09.deviantart.net/fs71/PRE/i/2013/361/7/c/pokemon_gengar_human_by_marazh2104lovetu-d6zlfot.jpg
# [INFO] skipping: http://th09.deviantart.net/fs71/PRE/i/2013/361/7/c/pokemon_gengar_human_by_marazh2104lovetu-d6zlfot.jpg
# [INFO] fetching: https://66.media.tumblr.com/8c2769b79fd71587c2c2979f589fc3d2/tumblr_ns7f2uYKRM1rns4t9o1_500.gif
# [INFO] skipping: https://66.media.tumblr.com/8c2769b79fd71587c2c2979f589fc3d2/tumblr_ns7f2uYKRM1rns4t9o1_500.gif
# [INFO] fetching: http://img12.deviantart.net/a001/i/2014/115/9/f/gengar_by_sixfrid-d7fx483.jpg
# [INFO] skipping: http://img12.deviantart.net/a001/i/2014/115/9/f/gengar_by_sixfrid-d7fx483.jpg
# [INFO] fetching: https://zelkedark.files.wordpress.com/2013/06/tumblr_lm2fdulfif1qgj2rto1_1280.jpg
# [INFO] skipping: https://zelkedark.files.wordpress.com/2013/06/tumblr_lm2fdulfif1qgj2rto1_1280.jpg
# [INFO] fetching: http://orig00.deviantart.net/8c93/f/2015/210/5/6/gengar_by_stan5582-d93a3qp.jpg
# [INFO] skipping: http://orig00.deviantart.net/8c93/f/2015/210/5/6/gengar_by_stan5582-d93a3qp.jpg
# [INFO] fetching: http://static.giantbomb.com/uploads/original/9/98500/2437910-gengar.jpg
# [INFO] skipping: http://static.giantbomb.com/uploads/original/9/98500/2437910-gengar.jpg
# [INFO] fetching: https://cdn.wallpapersafari.com/49/59/9WhDUm.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/49/59/9WhDUm.jpg
# [INFO] fetching: http://sixprizes.com/wp-content/uploads/Gengar-Stormfront-SF-18.jpg
# [INFO] skipping: http://sixprizes.com/wp-content/uploads/Gengar-Stormfront-SF-18.jpg
# [INFO] fetching: http://i3.kym-cdn.com/photos/images/original/001/194/919/b73.jpg
# [INFO] skipping: http://i3.kym-cdn.com/photos/images/original/001/194/919/b73.jpg
# [INFO] fetching: http://fc00.deviantart.net/fs70/i/2013/097/6/f/094___gengar___art_v_2_by_tails19950-d60r9yi.png
# [INFO] skipping: http://fc00.deviantart.net/fs70/i/2013/097/6/f/094___gengar___art_v_2_by_tails19950-d60r9yi.png
# [INFO] fetching: http://wallpapercave.com/wp/M76B1PF.jpg
# [INFO] skipping: http://wallpapercave.com/wp/M76B1PF.jpg
# 150
# [INFO] making request for group 150-200 of 250...
# [INFO] saving images for group 150-200 of 250...
# [INFO] fetching: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-Wallpapers-HD.jpg
# [INFO] skipping: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-Wallpapers-HD.jpg
# [INFO] fetching: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-HD-Wallpaper.jpg
# [INFO] skipping: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-HD-Wallpaper.jpg
# [INFO] fetching: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-High-Definition-Wallpapers.jpg
# [INFO] skipping: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-High-Definition-Wallpapers.jpg
# [INFO] fetching: https://i.pinimg.com/736x/ec/6e/6c/ec6e6c4f3f6bbbbdb70988d4bbb6b24d--charmeleon-pokemon-yahoo-search.jpg
# [INFO] skipping: https://i.pinimg.com/736x/ec/6e/6c/ec6e6c4f3f6bbbbdb70988d4bbb6b24d--charmeleon-pokemon-yahoo-search.jpg
# [INFO] fetching: https://nintendoeverything.com/wp-content/uploads/gengar.png
# [INFO] skipping: https://nintendoeverything.com/wp-content/uploads/gengar.png
# [INFO] fetching: https://cdn.wallpapersafari.com/10/25/EiP5r3.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/10/25/EiP5r3.jpg
# [INFO] fetching: http://i3.kym-cdn.com/photos/images/original/001/194/919/b73.jpg
# [INFO] skipping: http://i3.kym-cdn.com/photos/images/original/001/194/919/b73.jpg
# [INFO] fetching: https://cdn.weasyl.com/~ijdraws/submissions/1150377/02a6a7fc79de66010bb771bbaccabea2a9b4a9f19c9272e416fb5d0fc1d411c1/ijdraws-gengar.png
# [INFO] skipping: https://cdn.weasyl.com/~ijdraws/submissions/1150377/02a6a7fc79de66010bb771bbaccabea2a9b4a9f19c9272e416fb5d0fc1d411c1/ijdraws-gengar.png
# [INFO] fetching: http://th09.deviantart.net/fs71/PRE/i/2013/361/7/c/pokemon_gengar_human_by_marazh2104lovetu-d6zlfot.jpg
# [INFO] skipping: http://th09.deviantart.net/fs71/PRE/i/2013/361/7/c/pokemon_gengar_human_by_marazh2104lovetu-d6zlfot.jpg
# [INFO] fetching: https://ae01.alicdn.com/kf/HTB1MrrJcFmWBuNjSspdq6zugXXa9/1Piece-Pokemon-Inspired-LED-Wall-Light-Remote-Activated-Gengar-Pokemon-LED-Backlit-Wall-Art-Color-Changing.jpg
# [INFO] skipping: https://ae01.alicdn.com/kf/HTB1MrrJcFmWBuNjSspdq6zugXXa9/1Piece-Pokemon-Inspired-LED-Wall-Light-Remote-Activated-Gengar-Pokemon-LED-Backlit-Wall-Art-Color-Changing.jpg
# [INFO] fetching: http://orig00.deviantart.net/8c93/f/2015/210/5/6/gengar_by_stan5582-d93a3qp.jpg
# [INFO] skipping: http://orig00.deviantart.net/8c93/f/2015/210/5/6/gengar_by_stan5582-d93a3qp.jpg
# [INFO] fetching: http://cdn.wallpapersafari.com/29/54/lug5yT.png
# [INFO] skipping: http://cdn.wallpapersafari.com/29/54/lug5yT.png
# [INFO] fetching: https://cdn.wallpapersafari.com/69/65/rvZsUW.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/69/65/rvZsUW.jpg
# [INFO] fetching: https://pokewalls.files.wordpress.com/2011/01/94gengar1-1600x1200.jpg
# [INFO] skipping: https://pokewalls.files.wordpress.com/2011/01/94gengar1-1600x1200.jpg
# [INFO] fetching: https://i.ytimg.com/vi/svV8Bu_wS6o/maxresdefault.jpg
# [INFO] skipping: https://i.ytimg.com/vi/svV8Bu_wS6o/maxresdefault.jpg
# [INFO] fetching: http://img07.deviantart.net/0f19/i/2011/175/c/7/gengar___commission_by_soupandbutter-d3jtlrm.jpg
# [INFO] skipping: http://img07.deviantart.net/0f19/i/2011/175/c/7/gengar___commission_by_soupandbutter-d3jtlrm.jpg
# [INFO] fetching: http://sixprizes.com/wp-content/uploads/Gengar-Stormfront-SF-18.jpg
# [INFO] skipping: http://sixprizes.com/wp-content/uploads/Gengar-Stormfront-SF-18.jpg
# [INFO] fetching: http://fc06.deviantart.net/fs71/f/2014/002/a/2/gengar_by_kiki_myaki-d70gqu5.png
# [INFO] skipping: http://fc06.deviantart.net/fs71/f/2014/002/a/2/gengar_by_kiki_myaki-d70gqu5.png
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/8f/ab/0a/8fab0a0132089626b89f0b9ef23c3c06.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/8f/ab/0a/8fab0a0132089626b89f0b9ef23c3c06.jpg
# [INFO] fetching: https://i.pinimg.com/736x/39/b1/4c/39b14c10897d0613f5c903cdadcf5112.jpg
# [INFO] skipping: https://i.pinimg.com/736x/39/b1/4c/39b14c10897d0613f5c903cdadcf5112.jpg
# [INFO] fetching: https://cdn.wallpapersafari.com/80/76/9hP3ls.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/80/76/9hP3ls.jpg
# [INFO] fetching: https://cdn.wallpapersafari.com/9/56/CFHejG.png
# [INFO] skipping: https://cdn.wallpapersafari.com/9/56/CFHejG.png
# [INFO] fetching: http://www.itaniumsolutions.org/pics/max/95/958905_gengar-wallpaper.jpg
# [INFO] skipping: http://www.itaniumsolutions.org/pics/max/95/958905_gengar-wallpaper.jpg
# [INFO] fetching: https://farm8.static.flickr.com/7015/6840632485_7d6752d43d_b.jpg
# [INFO] skipping: https://farm8.static.flickr.com/7015/6840632485_7d6752d43d_b.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/89/e9/5a/89e95aaac2170785010bec99f29bf41e.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/89/e9/5a/89e95aaac2170785010bec99f29bf41e.jpg
# [INFO] fetching: http://wallpapercave.com/wp/G5u5K3P.png
# [INFO] skipping: http://wallpapercave.com/wp/G5u5K3P.png
# [INFO] fetching: http://img00.deviantart.net/fe26/i/2015/215/d/2/094_gengar_by_tamtamdi-d93yumz.jpg
# [INFO] skipping: http://img00.deviantart.net/fe26/i/2015/215/d/2/094_gengar_by_tamtamdi-d93yumz.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/f1/55/7b/f1557bd2d078b0d72bb26f0ae1190b3a.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/f1/55/7b/f1557bd2d078b0d72bb26f0ae1190b3a.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/originals/09/69/48/0969485a96b79ca75335dc920fac2128.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/originals/09/69/48/0969485a96b79ca75335dc920fac2128.jpg
# [INFO] fetching: https://mir-s3-cdn-cf.behance.net/project_modules/1400/cd3d0943394131.57ed4e028ea89.jpg
# [INFO] skipping: https://mir-s3-cdn-cf.behance.net/project_modules/1400/cd3d0943394131.57ed4e028ea89.jpg
# [INFO] fetching: http://th04.deviantart.net/fs70/PRE/i/2011/283/9/6/hipster_gengar_by_ainfinity-d4ce3mx.png
# [INFO] skipping: http://th04.deviantart.net/fs70/PRE/i/2011/283/9/6/hipster_gengar_by_ainfinity-d4ce3mx.png
# [INFO] fetching: http://fc04.deviantart.net/fs70/i/2013/283/5/f/mega_gengar_by_theangryaron-d6peqe8.png
# [INFO] skipping: http://fc04.deviantart.net/fs70/i/2013/283/5/f/mega_gengar_by_theangryaron-d6peqe8.png
# [INFO] fetching: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P4514/710-03475/P4514_710-03475_06.jpg
# [INFO] skipping: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P4514/710-03475/P4514_710-03475_06.jpg
# [INFO] fetching: https://wallpaperplay.com/walls/full/1/4/6/125852.jpg
# [INFO] skipping: https://wallpaperplay.com/walls/full/1/4/6/125852.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/71/dd/be/71ddbe5d7bceb5df6df80bed0f399a14.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/71/dd/be/71ddbe5d7bceb5df6df80bed0f399a14.jpg
# [INFO] fetching: http://vignette3.wikia.nocookie.net/pokemon/images/2/2e/Cole_Gengar.png/revision/latest?cb=20150519204205
# [INFO] skipping: http://vignette3.wikia.nocookie.net/pokemon/images/2/2e/Cole_Gengar.png/revision/latest?cb=20150519204205
# [INFO] fetching: https://static.zerochan.net/Gengar.full.1916577.jpg
# [INFO] skipping: https://static.zerochan.net/Gengar.full.1916577.jpg
# [INFO] fetching: https://i.ytimg.com/vi/4Fiit0kk6WU/maxresdefault.jpg
# [INFO] skipping: https://i.ytimg.com/vi/4Fiit0kk6WU/maxresdefault.jpg
# [INFO] fetching: http://th04.deviantart.net/fs70/PRE/i/2011/284/b/b/gengar_cheshire_cat_shirt_by_fishmas-d4cjjay.jpg
# [INFO] skipping: http://th04.deviantart.net/fs70/PRE/i/2011/284/b/b/gengar_cheshire_cat_shirt_by_fishmas-d4cjjay.jpg
# [INFO] fetching: http://img12.deviantart.net/45d8/i/2016/212/2/6/gastly_evolutions_by_nohbyl-dabqche.jpg
# [INFO] skipping: http://img12.deviantart.net/45d8/i/2016/212/2/6/gastly_evolutions_by_nohbyl-dabqche.jpg
# [INFO] fetching: https://cdn.thingiverse.com/assets/a3/e1/4c/9c/22/RIMG0182.JPG
# [INFO] skipping: https://cdn.thingiverse.com/assets/a3/e1/4c/9c/22/RIMG0182.JPG
# [INFO] fetching: https://cdn.wallpapersafari.com/73/9/ayoQZ3.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/73/9/ayoQZ3.jpg
# [INFO] fetching: http://3.bp.blogspot.com/-vs_tf5TSobM/VkN5nSwM0jI/AAAAAAAABuk/fAYxU7WD7F0/s1600/grim_haunter_by_kokodriliscus-d6z19jy.jpg
# [INFO] skipping: http://3.bp.blogspot.com/-vs_tf5TSobM/VkN5nSwM0jI/AAAAAAAABuk/fAYxU7WD7F0/s1600/grim_haunter_by_kokodriliscus-d6z19jy.jpg
# [INFO] fetching: http://fc04.deviantart.net/fs71/i/2011/209/2/3/gengar_gijinka_by_chiliwillies-d41zg48.jpg
# [INFO] skipping: http://fc04.deviantart.net/fs71/i/2011/209/2/3/gengar_gijinka_by_chiliwillies-d41zg48.jpg
# [INFO] fetching: http://i.imgur.com/H2r51Xn.jpg
# [INFO] skipping: http://i.imgur.com/H2r51Xn.jpg
# [INFO] fetching: https://theinsightfulpanda.files.wordpress.com/2014/09/shiny-gengar-diancie.png
# [INFO] skipping: https://theinsightfulpanda.files.wordpress.com/2014/09/shiny-gengar-diancie.png
# [INFO] fetching: http://fc09.deviantart.net/fs70/i/2014/211/8/a/mega_gengar___nightmare_by_ishmam-d7s6i6z.png
# [INFO] skipping: http://fc09.deviantart.net/fs70/i/2014/211/8/a/mega_gengar___nightmare_by_ishmam-d7s6i6z.png
# [INFO] fetching: https://i1.wp.com/www.miahandcrafter.com/atelier/wp-content/uploads/2012/10/gengar3.jpg
# [INFO] skipping: https://i1.wp.com/www.miahandcrafter.com/atelier/wp-content/uploads/2012/10/gengar3.jpg
# [INFO] fetching: https://wallpapertag.com/wallpaper/full/f/1/c/357572-top-gengar-wallpaper-1980x1080-hd-for-mobile.jpg
# [INFO] skipping: https://wallpapertag.com/wallpaper/full/f/1/c/357572-top-gengar-wallpaper-1980x1080-hd-for-mobile.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/86/b4/28/86b42821106efed44dfe8db358462ec1.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/86/b4/28/86b42821106efed44dfe8db358462ec1.jpg
# 200
# [INFO] making request for group 200-250 of 250...
# [INFO] saving images for group 200-250 of 250...
# [INFO] fetching: https://wallpapertag.com/wallpaper/full/f/1/c/357572-top-gengar-wallpaper-1980x1080-hd-for-mobile.jpg
# [INFO] skipping: https://wallpapertag.com/wallpaper/full/f/1/c/357572-top-gengar-wallpaper-1980x1080-hd-for-mobile.jpg
# [INFO] fetching: https://wallpaperplay.com/walls/full/1/4/6/125852.jpg
# [INFO] skipping: https://wallpaperplay.com/walls/full/1/4/6/125852.jpg
# [INFO] fetching: http://vignette3.wikia.nocookie.net/pokemon/images/2/2e/Cole_Gengar.png/revision/latest?cb=20150519204205
# [INFO] skipping: http://vignette3.wikia.nocookie.net/pokemon/images/2/2e/Cole_Gengar.png/revision/latest?cb=20150519204205
# [INFO] fetching: https://cdn.thingiverse.com/assets/a3/e1/4c/9c/22/RIMG0182.JPG
# [INFO] skipping: https://cdn.thingiverse.com/assets/a3/e1/4c/9c/22/RIMG0182.JPG
# [INFO] fetching: http://th04.deviantart.net/fs70/PRE/i/2011/284/b/b/gengar_cheshire_cat_shirt_by_fishmas-d4cjjay.jpg
# [INFO] skipping: http://th04.deviantart.net/fs70/PRE/i/2011/284/b/b/gengar_cheshire_cat_shirt_by_fishmas-d4cjjay.jpg
# [INFO] fetching: https://static.zerochan.net/Gengar.full.1916577.jpg
# [INFO] skipping: https://static.zerochan.net/Gengar.full.1916577.jpg
# [INFO] fetching: https://i.ytimg.com/vi/4Fiit0kk6WU/maxresdefault.jpg
# [INFO] skipping: https://i.ytimg.com/vi/4Fiit0kk6WU/maxresdefault.jpg
# [INFO] fetching: http://img12.deviantart.net/45d8/i/2016/212/2/6/gastly_evolutions_by_nohbyl-dabqche.jpg
# [INFO] skipping: http://img12.deviantart.net/45d8/i/2016/212/2/6/gastly_evolutions_by_nohbyl-dabqche.jpg
# [INFO] fetching: http://fc04.deviantart.net/fs71/i/2011/209/2/3/gengar_gijinka_by_chiliwillies-d41zg48.jpg
# [INFO] skipping: http://fc04.deviantart.net/fs71/i/2011/209/2/3/gengar_gijinka_by_chiliwillies-d41zg48.jpg
# [INFO] fetching: http://3.bp.blogspot.com/-vs_tf5TSobM/VkN5nSwM0jI/AAAAAAAABuk/fAYxU7WD7F0/s1600/grim_haunter_by_kokodriliscus-d6z19jy.jpg
# [INFO] skipping: http://3.bp.blogspot.com/-vs_tf5TSobM/VkN5nSwM0jI/AAAAAAAABuk/fAYxU7WD7F0/s1600/grim_haunter_by_kokodriliscus-d6z19jy.jpg
# [INFO] fetching: http://i.imgur.com/H2r51Xn.jpg
# [INFO] skipping: http://i.imgur.com/H2r51Xn.jpg
# [INFO] fetching: http://orig05.deviantart.net/4f37/f/2013/351/2/b/mega_gengar_by_perfect1up-d6yd7wj.png
# [INFO] skipping: http://orig05.deviantart.net/4f37/f/2013/351/2/b/mega_gengar_by_perfect1up-d6yd7wj.png
# [INFO] fetching: http://fc09.deviantart.net/fs70/i/2014/211/8/a/mega_gengar___nightmare_by_ishmam-d7s6i6z.png
# [INFO] skipping: http://fc09.deviantart.net/fs70/i/2014/211/8/a/mega_gengar___nightmare_by_ishmam-d7s6i6z.png
# [INFO] fetching: https://i1.wp.com/www.miahandcrafter.com/atelier/wp-content/uploads/2012/10/gengar3.jpg
# [INFO] skipping: https://i1.wp.com/www.miahandcrafter.com/atelier/wp-content/uploads/2012/10/gengar3.jpg
# [INFO] fetching: https://i.ytimg.com/vi/9m1VQjmzpzs/maxresdefault.jpg
# [INFO] skipping: https://i.ytimg.com/vi/9m1VQjmzpzs/maxresdefault.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/99/b9/87/99b987f91dc64090b729f83ce2706127.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/99/b9/87/99b987f91dc64090b729f83ce2706127.jpg
# [INFO] fetching: http://getwallpapers.com/wallpaper/full/2/5/0/105221.jpg
# [INFO] skipping: http://getwallpapers.com/wallpaper/full/2/5/0/105221.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/8c/d2/80/8cd28064062d0551320212accf9ecb48.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/8c/d2/80/8cd28064062d0551320212accf9ecb48.jpg
# [INFO] fetching: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-Images.jpg
# [INFO] skipping: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-Images.jpg
# [INFO] fetching: http://fc05.deviantart.net/images3/i/2004/11/f/5/Gengar__s_Revenge.jpg
# [INFO] skipping: http://fc05.deviantart.net/images3/i/2004/11/f/5/Gengar__s_Revenge.jpg
# [INFO] fetching: http://cdn.wallpapersafari.com/26/6/Dz05lE.png
# [INFO] skipping: http://cdn.wallpapersafari.com/26/6/Dz05lE.png
# [INFO] fetching: https://cdn.shopify.com/s/files/1/1677/4363/products/Gengar_GX_fe45ab78-c19d-4848-9ae7-fff25424d7f0_530x@2x.jpg?v=1508083804
# [INFO] skipping: https://cdn.shopify.com/s/files/1/1677/4363/products/Gengar_GX_fe45ab78-c19d-4848-9ae7-fff25424d7f0_530x@2x.jpg?v=1508083804
# [INFO] fetching: https://cdn.vox-cdn.com/thumbor/--WuIH8hU_sOLF3RIMPHrjAXV6s=/62x0:737x450/1200x800/filters:focal(62x0:737x450)/cdn.vox-cdn.com/uploads/chorus_image/image/42841472/gengar_junji_ito.0.0.jpg
# [INFO] skipping: https://cdn.vox-cdn.com/thumbor/--WuIH8hU_sOLF3RIMPHrjAXV6s=/62x0:737x450/1200x800/filters:focal(62x0:737x450)/cdn.vox-cdn.com/uploads/chorus_image/image/42841472/gengar_junji_ito.0.0.jpg
# [INFO] fetching: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2300/710-01676/P2300_710-01676_05.jpg
# [INFO] skipping: https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2300/710-01676/P2300_710-01676_05.jpg
# [INFO] fetching: http://24.media.tumblr.com/tumblr_mayr7cbiPI1qe4fy4o1_500.jpg
# [INFO] skipping: http://24.media.tumblr.com/tumblr_mayr7cbiPI1qe4fy4o1_500.jpg
# [INFO] fetching: https://i.ytimg.com/vi/B30YqWkUZTg/maxresdefault.jpg
# [INFO] skipping: https://i.ytimg.com/vi/B30YqWkUZTg/maxresdefault.jpg
# [INFO] fetching: http://fc07.deviantart.net/fs17/f/2007/145/b/6/Gengar__Shadow_Ball_by_RapidPowerBlast.jpg
# [INFO] skipping: http://fc07.deviantart.net/fs17/f/2007/145/b/6/Gengar__Shadow_Ball_by_RapidPowerBlast.jpg
# [INFO] fetching: http://cdn.instructables.com/FE6/YD89/GFRWRGV5/FE6YD89GFRWRGV5.RECT2100.jpg
# [INFO] skipping: http://cdn.instructables.com/FE6/YD89/GFRWRGV5/FE6YD89GFRWRGV5.RECT2100.jpg
# [INFO] fetching: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P1583/701-00484/P1583_701-00484_02.jpg
# [INFO] skipping: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P1583/701-00484/P1583_701-00484_02.jpg
# [INFO] fetching: https://www.technobuffalo.com/wp-content/uploads/2014/09/Shiny-Gengar-2.jpg
# [INFO] skipping: https://www.technobuffalo.com/wp-content/uploads/2014/09/Shiny-Gengar-2.jpg
# [INFO] fetching: https://wallpaperaccess.com/full/560448.jpg
# [INFO] skipping: https://wallpaperaccess.com/full/560448.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/4c/4d/07/4c4d071496a38b87ca9eb339b4a9542b.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/4c/4d/07/4c4d071496a38b87ca9eb339b4a9542b.jpg
# [INFO] fetching: https://images.fun.com/products/29366/2-1-70056/pokemon-gengar-namedrop-juniors-t-shirt2.jpg
# [INFO] skipping: https://images.fun.com/products/29366/2-1-70056/pokemon-gengar-namedrop-juniors-t-shirt2.jpg
# [INFO] fetching: http://getwallpapers.com/wallpaper/full/c/a/9/324557.jpg
# [INFO] skipping: http://getwallpapers.com/wallpaper/full/c/a/9/324557.jpg
# [INFO] fetching: http://pre10.deviantart.net/53a9/th/pre/f/2015/274/1/4/gengar_pattern_by_andcetera-d9bkog9.png
# [INFO] skipping: http://pre10.deviantart.net/53a9/th/pre/f/2015/274/1/4/gengar_pattern_by_andcetera-d9bkog9.png
# [INFO] fetching: https://img0.etsystatic.com/101/0/9555747/il_fullxfull.836048276_jvz2.jpg
# [INFO] skipping: https://img0.etsystatic.com/101/0/9555747/il_fullxfull.836048276_jvz2.jpg
# [INFO] fetching: https://s-media-cache-ak0.pinimg.com/736x/86/b4/28/86b42821106efed44dfe8db358462ec1.jpg
# [INFO] skipping: https://s-media-cache-ak0.pinimg.com/736x/86/b4/28/86b42821106efed44dfe8db358462ec1.jpg
# [INFO] fetching: http://wallpapercave.com/wp/x5Td0O0.jpg
# [INFO] skipping: http://wallpapercave.com/wp/x5Td0O0.jpg
# [INFO] fetching: https://i.pinimg.com/736x/73/22/16/7322162e099233f8f38c4e904efe16ea--pokemon-mix-pokemon-stuff.jpg
# [INFO] skipping: https://i.pinimg.com/736x/73/22/16/7322162e099233f8f38c4e904efe16ea--pokemon-mix-pokemon-stuff.jpg
# [INFO] fetching: http://vignette2.wikia.nocookie.net/pokemon/images/f/f1/Haunter_Gengar_JE005.png/revision/latest?cb=20150628062831
# [INFO] skipping: http://vignette2.wikia.nocookie.net/pokemon/images/f/f1/Haunter_Gengar_JE005.png/revision/latest?cb=20150628062831
# [INFO] fetching: https://cdn.wallpapersafari.com/32/67/nRCmiW.jpg
# [INFO] skipping: https://cdn.wallpapersafari.com/32/67/nRCmiW.jpg
# [INFO] fetching: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-for-desktop.jpg
# [INFO] skipping: http://wallpapersdsc.net/wp-content/uploads/2016/09/Gengar-for-desktop.jpg
# [INFO] fetching: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2682/741-02320/P2682_741-02320_01.jpg
# [INFO] skipping: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2682/741-02320/P2682_741-02320_01.jpg
# [INFO] fetching: https://cdn.wallpapersafari.com/71/45/i9FU4P.png
# [INFO] skipping: https://cdn.wallpapersafari.com/71/45/i9FU4P.png
# [INFO] fetching: http://orig04.deviantart.net/8a72/f/2012/030/4/7/my_neighbor_gengar_by_mscorley-d4o48qh.gif
# [INFO] skipping: http://orig04.deviantart.net/8a72/f/2012/030/4/7/my_neighbor_gengar_by_mscorley-d4o48qh.gif
# [INFO] fetching: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2932/701-00065/P2932_701-00065_01.jpg
# [INFO] skipping: http://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P2932/701-00065/P2932_701-00065_01.jpg
# [INFO] fetching: https://wallpapercave.com/wp/wp2442637.jpg
# [INFO] skipping: https://wallpapercave.com/wp/wp2442637.jpg
# [INFO] fetching: http://wallpoper.com/images/00/33/93/69/pokemon-gengar_00339369.jpg
# [INFO] skipping: http://wallpoper.com/images/00/33/93/69/pokemon-gengar_00339369.jpg
# [INFO] fetching: http://getwallpapers.com/wallpaper/full/f/2/1/49755.jpg
# [INFO] skipping: http://getwallpapers.com/wallpaper/full/f/2/1/49755.jpg
# [INFO] fetching: http://orig12.deviantart.net/627e/f/2014/139/5/d/gengar__the_shadow_pokemon_by_slurpoof-d7iyr37.png
# [INFO] skipping: http://orig12.deviantart.net/627e/f/2014/139/5/d/gengar__the_shadow_pokemon_by_slurpoof-d7iyr37.png
# 250

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-15bcf641-449d-4fd2-8b54-2cfb5cbb8713" name="files[]" multiple disabled />
#      <output id="result-15bcf641-449d-4fd2-8b54-2cfb5cbb8713">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !unzip pyimagesearch.zip
# Out:
# unzip:  cannot find or open pyimagesearch.zip, pyimagesearch.zip.zip or pyimagesearch.zip.ZIP.

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
class SmallerVGGNet:
	@staticmethod
	def build(width, height, depth, classes):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (height, width, depth)
		chanDim = -1
 
		# if we are using "channels first", update the input shape
		# and channels dimension
		if K.image_data_format() == "channels_first":
			inputShape = (depth, height, width)
			chanDim = 1
      # CONV => RELU => POOL
		model.add(Conv2D(32, (3, 3), padding="same",
			input_shape=inputShape))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(3, 3)))
		model.add(Dropout(0.25))
    # (CONV => RELU) * 2 => POOL
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))
    # (CONV => RELU) * 2 => POOL
		model.add(Conv2D(128, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(128, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))
    # first (and only) set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(1024))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))
 
		# softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))
 
		# return the constructed network architecture
		return model

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# ··········

# %%
# !ls
# Out:
# adc.json  drive  sample_data

# %%
# 指定Google Drive云端硬盘的根目录，名为drive
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# fuse: mountpoint is not empty
# fuse: if you are sure this is safe, use the 'nonempty' mount option

# %%
# 指定当前的工作文件夹
import os

# 此处为google drive中的文件路径,drive为之前指定的工作根目录，要加上
os.chdir("adc.json  drive  sample_data/cnn-keras")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-edf28106d5a7> in <module>()
#       2
#       3 # 此处为google drive中的文件路径,drive为之前指定的工作根目录，要加上
# ----> 4 os.chdir("adc.json  drive  sample_data/cnn-keras")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'adc.json  drive  sample_data/cnn-keras'
